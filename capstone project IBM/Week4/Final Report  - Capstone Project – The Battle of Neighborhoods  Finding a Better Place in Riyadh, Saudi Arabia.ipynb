# %% [markdown]
# # Final Report | Capstone Project – Finding a Better Place in Riyadh, Saudi Arabia

# %% [markdown]
# ## 1. Introduction:
#
# The purpose of this Project is to help people in exploring better facilities around their neighborhood. It will help people making smart and efficient decision on selecting great neighborhood out of numbers of other neighborhoods in Riyadh, Saudi Arabia.
#
# Thsi project is for new movers to Riyadh to better decide on the neighbourhood. For ease of accessing to Cafe, School, Super market, medical shops, grocery shops, mall, theatre, hospital, like minded people, etc.
#
# This Project aim to create an analysis of features for a people migrating to Riyadh to search a best neighborhood as a comparative analysis between neighborhoods.
#
# It will help people to get awareness of the area and neighborhood before moving to a new city, state, country or place for their work or to start a new fresh life.
#
#
#
# ## 2. Data Section
#
# Data Link: https://en.wikipedia.org/wiki/Riyadh
#
# The Neighbourhood list is taken from the above link and the longitude and latitude data will be gathered through scraping.
#
#
# ## Foursquare API Data:
#
# We will need data about different venues in different neighborhoods.
# In order to gain that information we will use "Foursquare" locational information. Foursquare is a location data provider with information about all manner of venues and events within an area of interest. Such information includes venue names, locations, menus and even photos. As such, the foursquare location platform will be used as the sole data source since all the stated required information can be obtained through the API.
#
# After finding the list of neighborhoods, we then connect to the Foursquare API to gather information about venues inside each and every neighborhood.
#
# The data retrieved from Foursquare contained information of venues within a specified distance of the longitude and latitude of the postcodes. The information obtained per venue as follows:
#
#     1. Neighborhood
#     2. Neighborhood Latitude
#     3. Neighborhood Longitude
#     4. Venue
#     5. Name of the venue e.g. the name of a store or restaurant
#     6. Venue Latitude
#     7. Venue Longitude
#     8. Venue Category
#
#
# ## 3. Methodology Section
#
# #### Clustering Approach:
# To find miliarities between different neigbourhoods of the Riyadh City. To be able to do that, we need to cluster data which is a form of unsupervised machine learning: k-means clustering algorithm.
#
# #### Work Flow:
# Using credentials of Foursquare API features of near-by places of the neighborhoods would be mined. Due to http request limitations the number of places per neighborhood parameter would reasonably be set to 100 and the radius parameter would be set to 500.
#
#
#
# ## 4. Results Section
#
# **Map of Clusters in Riyadh**
# > ![title](map.png)
#
# Results: The neighbourhoods are divided into different groups based on similaritites
#
# **Heatmap of cluster 1 (purple)**
# Results: the gardens cafes and resturants are particularly prominent in the cluster
# > ![t](cluster1.png)
#
#
#
# **Heatmap of cluster 6 (light blue)**
# Results: the middle eastern resturants and metrostations are particularly prominent in the cluster
# > ![t](cluster6.png)
#
#
#
#
#
#
#
# **Heatmap of cluster 15,16 (orange/yellow)**
#
# Results: Parks and coffee shops are prominent places in the yellow/orrange clusters
#
# > ![t](cluster15,16.png)
#
#
#
# #### The Location:
# Riyadh is a the Capital of Saudi Arabia. Almost 40% of the population is expatriates. As a result, it is one of the most diverse and multicultural areas.
#
# #### Foursquare API:
# This project would use Four-square API as its prime data gathering source as it has a database of millions of places, especially their places API which provides the ability to perform location search, location sharing and details about a business.
#
#
# #### Work Flow:
# Using credentials of Foursquare API features of near-by places of the neighborhoods would be mined.
#
#
#
# ## 5. Discussion Section
#
# #### Problem Which Tried to Solve:
# The major purpose of this project, is to suggest a better neighborhood in a new city for the person who are shiffting there. Social presence in society in terms of like minded people. Connectivity to the airport, bus stand, city center, markets and other daily needs things nearby.
#
#
# ## 6. Conclusion Section
#
# In this project, using k-means cluster algorithm I separated the neighborhood into 20(Ten) different clusters, which have very-similar neighborhoods around them.
#
# I feel rewarded with the efforts and believe this course with all the topics covered is well worthy of appreciation.
# This project has shown me a practical application to resolve a real situation that has impacting personal and financial impact using Data Science tools.
# The mapping with Folium is a very powerful technique to consolidate information and make the analysis and decision better with confidence.
#
#
# #### Future Works:
# This project can be continued for making it more precise in terms to find neighbourhood by collecting the housing price data.
#
# #### Libraries Which are Used to Develope the Project:
#
# > Pandas: For creating and manipulating dataframes.
# >
# > Folium: Python visualization library would be used to visualize the neighborhoods cluster distribution of using interactive leaflet map.
# >
# > Scikit Learn: For importing k-means clustering.
# >
# > JSON: Library to handle JSON files.
# >
# > XML: To separate data from presentation and XML stores data in plain text format.
# >
# > Geocoder: To retrieve Location Data.
# >
# > Beautiful Soup and Requests: To scrap and library to handle http requests.
# >
# > Matplotlib: Python Plotting Module.
#
# <br/>
